# %%
using JLD2
using CairoMakie

# %%
ids = ["", "_1", "_2", "_3", "_4", "_5", "_6", "_7", "_8", "_9", "_10", "_11"]
seeds = [26, 61, 70, 700, 709, 62, 63, 64, 65, 66, 67, 68]

for (id, seed) in zip(ids, seeds)
    tracks = load("./simulations/2026-05-25_sim_Fig_2_new_D0.1$id/groundtruth.jld2", "tracks")
    fig = Figure()
    ax = Axis(fig[1, 1], title="D=0.1, seed=$seed")
    lines!(ax, tracks[:, 1, 1], tracks[:, 2, 1])
    xlims!(1.3, 2.3)
    ylims!(1.3, 2.3)
    display(fig)
end
